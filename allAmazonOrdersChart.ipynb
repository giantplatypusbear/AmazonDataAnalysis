# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\Rithi\Downloads\amazondata.csv')
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   01/27/21  111-9984390-9483428             Visa - 3989  Amazon.com
# 1   04/08/21  111-9306215-0469859             Visa - 3989  Amazon.com
# 2   07/01/21  111-0893659-7112214             Visa - 3989  Amazon.com
# 3   07/01/21  111-0893659-7112214             Visa - 3989  Amazon.com
# 4   07/01/21  111-0893659-7112214             Visa - 3989  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    NaN     ritic1002@gmail.com      01/29/21
# 1                    NaN     ritic1002@gmail.com      04/10/21
# 2                    NaN     ritic1002@gmail.com      07/03/21
# 3                    NaN     ritic1002@gmail.com      07/05/21
# 4                    NaN     ritic1002@gmail.com      07/13/21
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0         Charlotte Chu           91 RIVERBEND DR                        NaN
# 1          Riti Chauhan           1304 JUNIPER CT                        NaN
# 2          Riti Chauhan           1304 JUNIPER CT                        NaN
# 3          Riti Chauhan           1304 JUNIPER CT                        NaN
# 4          Riti Chauhan           1304 JUNIPER CT                        NaN
#
#    ... Order Status Carrier Name & Tracking Number Subtotal Shipping Charge  \
# 0  ...      Shipped       AMZN_US(TBA151346121704)   $26.90           $7.38
# 1  ...      Shipped       AMZN_US(TBA026764593704)   $96.68          $15.07
# 2  ...      Shipped       AMZN_US(TBA113692711004)    $9.94           $1.34
# 3  ...      Shipped       AMZN_US(TBA115085337704)   $11.99           $3.67
# 4  ...      Shipped   USPS(9374889714090859123915)    $5.49           $2.47
#
#   Tax Before Promotions Total Promotions Tax Charged Total Charged  \
# 0                 $1.78            $7.38       $1.78        $28.68
# 1                 $6.41           $15.07       $6.41       $103.09
# 2                 $0.00            $1.34       $0.00         $9.94
# 3                 $0.00            $3.67       $0.00        $11.99
# 4                 $0.36            $2.47       $0.36         $5.85
#
#      Buyer Name Group Name
# 0  Riti Chauhan        NaN
# 1  Riti Chauhan        NaN
# 2  Riti Chauhan        NaN
# 3  Riti Chauhan        NaN
# 4  Riti Chauhan        NaN
#
# [5 rows x 23 columns]

# %%
df = df.fillna(0)
df["Total Charged"] = df["Total Charged"].str.replace('$','').astype(float)
df.head()
# Out:
# C:\Users\Rithi\AppData\Local\Temp\ipykernel_5496\3975561299.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Total Charged"] = df["Total Charged"].str.replace('$','').astype(float)
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   01/27/21  111-9984390-9483428             Visa - 3989  Amazon.com
# 1   04/08/21  111-9306215-0469859             Visa - 3989  Amazon.com
# 2   07/01/21  111-0893659-7112214             Visa - 3989  Amazon.com
# 3   07/01/21  111-0893659-7112214             Visa - 3989  Amazon.com
# 4   07/01/21  111-0893659-7112214             Visa - 3989  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0     ritic1002@gmail.com      01/29/21
# 1                    0.0     ritic1002@gmail.com      04/10/21
# 2                    0.0     ritic1002@gmail.com      07/03/21
# 3                    0.0     ritic1002@gmail.com      07/05/21
# 4                    0.0     ritic1002@gmail.com      07/13/21
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0         Charlotte Chu           91 RIVERBEND DR                        0.0
# 1          Riti Chauhan           1304 JUNIPER CT                        0.0
# 2          Riti Chauhan           1304 JUNIPER CT                        0.0
# 3          Riti Chauhan           1304 JUNIPER CT                        0.0
# 4          Riti Chauhan           1304 JUNIPER CT                        0.0
#
#    ... Order Status Carrier Name & Tracking Number Subtotal Shipping Charge  \
# 0  ...      Shipped       AMZN_US(TBA151346121704)   $26.90           $7.38
# 1  ...      Shipped       AMZN_US(TBA026764593704)   $96.68          $15.07
# 2  ...      Shipped       AMZN_US(TBA113692711004)    $9.94           $1.34
# 3  ...      Shipped       AMZN_US(TBA115085337704)   $11.99           $3.67
# 4  ...      Shipped   USPS(9374889714090859123915)    $5.49           $2.47
#
#   Tax Before Promotions Total Promotions Tax Charged Total Charged  \
# 0                 $1.78            $7.38       $1.78         28.68
# 1                 $6.41           $15.07       $6.41        103.09
# 2                 $0.00            $1.34       $0.00          9.94
# 3                 $0.00            $3.67       $0.00         11.99
# 4                 $0.36            $2.47       $0.36          5.85
#
#      Buyer Name Group Name
# 0  Riti Chauhan        0.0
# 1  Riti Chauhan        0.0
# 2  Riti Chauhan        0.0
# 3  Riti Chauhan        0.0
# 4  Riti Chauhan        0.0
#
# [5 rows x 23 columns]

# %%
df["Total Charged"].sum()
# Out:
# 1325.34

# %%
df["Total Charged"].max()
# Out:
# 210.05

# %%
df["Tax Charged"] = df["Tax Charged"].str.replace('$','').astype(float)
df["Tax Charged"].sum()
df["Tax Charged"].sum() / df["Total Charged"].sum()
# Out:
# C:\Users\Rithi\AppData\Local\Temp\ipykernel_5496\746753021.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Tax Charged"] = df["Tax Charged"].str.replace('$','').astype(float)
# 0.05435586340108954

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df.plot.bar(x='Order Date', y='Total Charged', rot=90)
# Out:
# <AxesSubplot:xlabel='Order Date'>
